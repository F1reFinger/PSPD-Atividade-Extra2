# %% [markdown]
# # importação inicial
# #### Neste notebook são as importações das libs para testar a instalação se esta tudo ok apos isso inserir celulas do projeto.

# %% [markdown]
# #### Libs

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pyspark

from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Test") \
    .master("local[*]") \
    .config("spark.hadoop.fs.defaultFS", "hdfs://namenode:9000") \
    .getOrCreate()

df = spark.read.text("hdfs://namenode:9000/input/texto.txt")
df.show()
